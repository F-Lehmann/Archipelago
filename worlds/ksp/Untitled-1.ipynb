# %%
with open('subjects.txt', 'r') as f:
    data = f.read().strip().split('\n')
    for i,subject in enumerate(data):
        parts = subject.split('@')
        experiment = parts[0]
        soi = parts[1]
        print(
            f'LOCATION_ID+{i}:'+'{'+f'\'name\':\'{subject}\',\'experiment\':\'{experiment}\',\'soi\':\'{soi}\''+'},')
# Out:
# LOCATION_ID+0:{'name':'atmosphereAnalysis@Duna','experiment':'atmosphereAnalysis','soi':'Duna'},
# LOCATION_ID+1:{'name':'atmosphereAnalysis@Eve','experiment':'atmosphereAnalysis','soi':'Eve'},
# LOCATION_ID+2:{'name':'atmosphereAnalysis@Kerbin','experiment':'atmosphereAnalysis','soi':'Kerbin'},
# LOCATION_ID+3:{'name':'atmosphereAnalysis@Laythe','experiment':'atmosphereAnalysis','soi':'Laythe'},
# LOCATION_ID+4:{'name':'barometerScan@Bop','experiment':'barometerScan','soi':'Bop'},
# LOCATION_ID+5:{'name':'barometerScan@Dres','experiment':'barometerScan','soi':'Dres'},
# LOCATION_ID+6:{'name':'barometerScan@Duna','experiment':'barometerScan','soi':'Duna'},
# LOCATION_ID+7:{'name':'barometerScan@Eeloo','experiment':'barometerScan','soi':'Eeloo'},
# LOCATION_ID+8:{'name':'barometerScan@Eve','experiment':'barometerScan','soi':'Eve'},
# LOCATION_ID+9:{'name':'barometerScan@Gilly','experiment':'barometerScan','soi':'Gilly'},
# LOCATION_ID+10:{'name':'barometerScan@Ike','experiment':'barometerScan','soi':'Ike'},
# LOCATION_ID+11:{'name':'barometerScan@Jool','experiment':'barometerScan','soi':'Jool'},
# LOCATION_ID+12:{'name':'barometerScan@Kerbin','experiment':'barometerScan','soi':'Kerbin'},
# LOCATION_ID+13:{'name':'barometerScan@Laythe','experiment':'barometerScan','soi':'Laythe'},
# LOCATION_ID+14:{'name':'barometerScan@Minmus','experiment':'barometerScan','soi':'Minmus'},
# LOCATION_ID+15:{'name':'barometerScan@Moho','experiment':'barometerScan','soi':'Moho'},
# LOCATION_ID+16:{'name':'barometerScan@Mun','experiment':'barometerScan','soi':'Mun'},
# LOCATION_ID+17:{'name':'barometerScan@Pol','experiment':'barometerScan','soi':'Pol'},
# LOCATION_ID+18:{'name':'barometerScan@Sun','experiment':'barometerScan','soi':'Sun'},
# LOCATION_ID+19:{'name':'barometerScan@Tylo','experiment':'barometerScan','soi':'Tylo'},
# LOCATION_ID+20:{'name':'barometerScan@Vall','experiment':'barometerScan','soi':'Vall'},
# LOCATION_ID+21:{'name':'crewReport@Bop','experiment':'crewReport','soi':'Bop'},
# LOCATION_ID+22:{'name':'crewReport@Dres','experiment':'crewReport','soi':'Dres'},
# LOCATION_ID+23:{'name':'crewReport@Duna','experiment':'crewReport','soi':'Duna'},
# LOCATION_ID+24:{'name':'crewReport@Eeloo','experiment':'crewReport','soi':'Eeloo'},
# LOCATION_ID+25:{'name':'crewReport@Eve','experiment':'crewReport','soi':'Eve'},
# LOCATION_ID+26:{'name':'crewReport@Gilly','experiment':'crewReport','soi':'Gilly'},
# LOCATION_ID+27:{'name':'crewReport@Ike','experiment':'crewReport','soi':'Ike'},
# LOCATION_ID+28:{'name':'crewReport@Jool','experiment':'crewReport','soi':'Jool'},
# LOCATION_ID+29:{'name':'crewReport@Kerbin','experiment':'crewReport','soi':'Kerbin'},
# LOCATION_ID+30:{'name':'crewReport@Laythe','experiment':'crewReport','soi':'Laythe'},
# LOCATION_ID+31:{'name':'crewReport@Minmus','experiment':'crewReport','soi':'Minmus'},
# LOCATION_ID+32:{'name':'crewReport@Moho','experiment':'crewReport','soi':'Moho'},
# LOCATION_ID+33:{'name':'crewReport@Mun','experiment':'crewReport','soi':'Mun'},
# LOCATION_ID+34:{'name':'crewReport@Pol','experiment':'crewReport','soi':'Pol'},
# LOCATION_ID+35:{'name':'crewReport@Sun','experiment':'crewReport','soi':'Sun'},
# LOCATION_ID+36:{'name':'crewReport@Tylo','experiment':'crewReport','soi':'Tylo'},
# LOCATION_ID+37:{'name':'crewReport@Vall','experiment':'crewReport','soi':'Vall'},
# LOCATION_ID+38:{'name':'evaReport@Bop','experiment':'evaReport','soi':'Bop'},
# LOCATION_ID+39:{'name':'evaReport@Dres','experiment':'evaReport','soi':'Dres'},
# LOCATION_ID+40:{'name':'evaReport@Duna','experiment':'evaReport','soi':'Duna'},
# LOCATION_ID+41:{'name':'evaReport@Eeloo','experiment':'evaReport','soi':'Eeloo'},
# LOCATION_ID+42:{'name':'evaReport@Eve','experiment':'evaReport','soi':'Eve'},
# LOCATION_ID+43:{'name':'evaReport@Gilly','experiment':'evaReport','soi':'Gilly'},
# LOCATION_ID+44:{'name':'evaReport@Ike','experiment':'evaReport','soi':'Ike'},
# LOCATION_ID+45:{'name':'evaReport@Jool','experiment':'evaReport','soi':'Jool'},
# LOCATION_ID+46:{'name':'evaReport@Kerbin','experiment':'evaReport','soi':'Kerbin'},
# LOCATION_ID+47:{'name':'evaReport@Laythe','experiment':'evaReport','soi':'Laythe'},
# LOCATION_ID+48:{'name':'evaReport@Minmus','experiment':'evaReport','soi':'Minmus'},
# LOCATION_ID+49:{'name':'evaReport@Moho','experiment':'evaReport','soi':'Moho'},
# LOCATION_ID+50:{'name':'evaReport@Mun','experiment':'evaReport','soi':'Mun'},
# LOCATION_ID+51:{'name':'evaReport@Pol','experiment':'evaReport','soi':'Pol'},
# LOCATION_ID+52:{'name':'evaReport@Sun','experiment':'evaReport','soi':'Sun'},
# LOCATION_ID+53:{'name':'evaReport@Tylo','experiment':'evaReport','soi':'Tylo'},
# LOCATION_ID+54:{'name':'evaReport@Vall','experiment':'evaReport','soi':'Vall'},
# LOCATION_ID+55:{'name':'gravityScan@Bop','experiment':'gravityScan','soi':'Bop'},
# LOCATION_ID+56:{'name':'gravityScan@Dres','experiment':'gravityScan','soi':'Dres'},
# LOCATION_ID+57:{'name':'gravityScan@Duna','experiment':'gravityScan','soi':'Duna'},
# LOCATION_ID+58:{'name':'gravityScan@Eeloo','experiment':'gravityScan','soi':'Eeloo'},
# LOCATION_ID+59:{'name':'gravityScan@Eve','experiment':'gravityScan','soi':'Eve'},
# LOCATION_ID+60:{'name':'gravityScan@Gilly','experiment':'gravityScan','soi':'Gilly'},
# LOCATION_ID+61:{'name':'gravityScan@Ike','experiment':'gravityScan','soi':'Ike'},
# LOCATION_ID+62:{'name':'gravityScan@Kerbin','experiment':'gravityScan','soi':'Kerbin'},
# LOCATION_ID+63:{'name':'gravityScan@Laythe','experiment':'gravityScan','soi':'Laythe'},
# LOCATION_ID+64:{'name':'gravityScan@Minmus','experiment':'gravityScan','soi':'Minmus'},
# LOCATION_ID+65:{'name':'gravityScan@Moho','experiment':'gravityScan','soi':'Moho'},
# LOCATION_ID+66:{'name':'gravityScan@Mun','experiment':'gravityScan','soi':'Mun'},
# LOCATION_ID+67:{'name':'gravityScan@Pol','experiment':'gravityScan','soi':'Pol'},
# LOCATION_ID+68:{'name':'gravityScan@Tylo','experiment':'gravityScan','soi':'Tylo'},
# LOCATION_ID+69:{'name':'gravityScan@Vall','experiment':'gravityScan','soi':'Vall'},
# LOCATION_ID+70:{'name':'infraredTelescope@Bop','experiment':'infraredTelescope','soi':'Bop'},
# LOCATION_ID+71:{'name':'infraredTelescope@Dres','experiment':'infraredTelescope','soi':'Dres'},
# LOCATION_ID+72:{'name':'infraredTelescope@Duna','experiment':'infraredTelescope','soi':'Duna'},
# LOCATION_ID+73:{'name':'infraredTelescope@Eeloo','experiment':'infraredTelescope','soi':'Eeloo'},
# LOCATION_ID+74:{'name':'infraredTelescope@Eve','experiment':'infraredTelescope','soi':'Eve'},
# LOCATION_ID+75:{'name':'infraredTelescope@Gilly','experiment':'infraredTelescope','soi':'Gilly'},
# LOCATION_ID+76:{'name':'infraredTelescope@Ike','experiment':'infraredTelescope','soi':'Ike'},
# LOCATION_ID+77:{'name':'infraredTelescope@Jool','experiment':'infraredTelescope','soi':'Jool'},
# LOCATION_ID+78:{'name':'infraredTelescope@Kerbin','experiment':'infraredTelescope','soi':'Kerbin'},
# LOCATION_ID+79:{'name':'infraredTelescope@Laythe','experiment':'infraredTelescope','soi':'Laythe'},
# LOCATION_ID+80:{'name':'infraredTelescope@Minmus','experiment':'infraredTelescope','soi':'Minmus'},
# LOCATION_ID+81:{'name':'infraredTelescope@Moho','experiment':'infraredTelescope','soi':'Moho'},
# LOCATION_ID+82:{'name':'infraredTelescope@Mun','experiment':'infraredTelescope','soi':'Mun'},
# LOCATION_ID+83:{'name':'infraredTelescope@Pol','experiment':'infraredTelescope','soi':'Pol'},
# LOCATION_ID+84:{'name':'infraredTelescope@Sun','experiment':'infraredTelescope','soi':'Sun'},
# LOCATION_ID+85:{'name':'infraredTelescope@Tylo','experiment':'infraredTelescope','soi':'Tylo'},
# LOCATION_ID+86:{'name':'infraredTelescope@Vall','experiment':'infraredTelescope','soi':'Vall'},
# LOCATION_ID+87:{'name':'magnetometer@Bop','experiment':'magnetometer','soi':'Bop'},
# LOCATION_ID+88:{'name':'magnetometer@Dres','experiment':'magnetometer','soi':'Dres'},
# LOCATION_ID+89:{'name':'magnetometer@Duna','experiment':'magnetometer','soi':'Duna'},
# LOCATION_ID+90:{'name':'magnetometer@Eeloo','experiment':'magnetometer','soi':'Eeloo'},
# LOCATION_ID+91:{'name':'magnetometer@Eve','experiment':'magnetometer','soi':'Eve'},
# LOCATION_ID+92:{'name':'magnetometer@Gilly','experiment':'magnetometer','soi':'Gilly'},
# LOCATION_ID+93:{'name':'magnetometer@Ike','experiment':'magnetometer','soi':'Ike'},
# LOCATION_ID+94:{'name':'magnetometer@Jool','experiment':'magnetometer','soi':'Jool'},
# LOCATION_ID+95:{'name':'magnetometer@Kerbin','experiment':'magnetometer','soi':'Kerbin'},
# LOCATION_ID+96:{'name':'magnetometer@Laythe','experiment':'magnetometer','soi':'Laythe'},
# LOCATION_ID+97:{'name':'magnetometer@Minmus','experiment':'magnetometer','soi':'Minmus'},
# LOCATION_ID+98:{'name':'magnetometer@Moho','experiment':'magnetometer','soi':'Moho'},
# LOCATION_ID+99:{'name':'magnetometer@Mun','experiment':'magnetometer','soi':'Mun'},
# LOCATION_ID+100:{'name':'magnetometer@Pol','experiment':'magnetometer','soi':'Pol'},
# LOCATION_ID+101:{'name':'magnetometer@Sun','experiment':'magnetometer','soi':'Sun'},
# LOCATION_ID+102:{'name':'magnetometer@Tylo','experiment':'magnetometer','soi':'Tylo'},
# LOCATION_ID+103:{'name':'magnetometer@Vall','experiment':'magnetometer','soi':'Vall'},
# LOCATION_ID+104:{'name':'mobileMaterialsLab@Bop','experiment':'mobileMaterialsLab','soi':'Bop'},
# LOCATION_ID+105:{'name':'mobileMaterialsLab@Dres','experiment':'mobileMaterialsLab','soi':'Dres'},
# LOCATION_ID+106:{'name':'mobileMaterialsLab@Duna','experiment':'mobileMaterialsLab','soi':'Duna'},
# LOCATION_ID+107:{'name':'mobileMaterialsLab@Eeloo','experiment':'mobileMaterialsLab','soi':'Eeloo'},
# LOCATION_ID+108:{'name':'mobileMaterialsLab@Eve','experiment':'mobileMaterialsLab','soi':'Eve'},
# LOCATION_ID+109:{'name':'mobileMaterialsLab@Gilly','experiment':'mobileMaterialsLab','soi':'Gilly'},
# LOCATION_ID+110:{'name':'mobileMaterialsLab@Ike','experiment':'mobileMaterialsLab','soi':'Ike'},
# LOCATION_ID+111:{'name':'mobileMaterialsLab@Jool','experiment':'mobileMaterialsLab','soi':'Jool'},
# LOCATION_ID+112:{'name':'mobileMaterialsLab@Kerbin','experiment':'mobileMaterialsLab','soi':'Kerbin'},
# LOCATION_ID+113:{'name':'mobileMaterialsLab@Laythe','experiment':'mobileMaterialsLab','soi':'Laythe'},
# LOCATION_ID+114:{'name':'mobileMaterialsLab@Minmus','experiment':'mobileMaterialsLab','soi':'Minmus'},
# LOCATION_ID+115:{'name':'mobileMaterialsLab@Moho','experiment':'mobileMaterialsLab','soi':'Moho'},
# LOCATION_ID+116:{'name':'mobileMaterialsLab@Mun','experiment':'mobileMaterialsLab','soi':'Mun'},
# LOCATION_ID+117:{'name':'mobileMaterialsLab@Pol','experiment':'mobileMaterialsLab','soi':'Pol'},
# LOCATION_ID+118:{'name':'mobileMaterialsLab@Sun','experiment':'mobileMaterialsLab','soi':'Sun'},
# LOCATION_ID+119:{'name':'mobileMaterialsLab@Tylo','experiment':'mobileMaterialsLab','soi':'Tylo'},
# LOCATION_ID+120:{'name':'mobileMaterialsLab@Vall','experiment':'mobileMaterialsLab','soi':'Vall'},
# LOCATION_ID+121:{'name':'mysteryGoo@Bop','experiment':'mysteryGoo','soi':'Bop'},
# LOCATION_ID+122:{'name':'mysteryGoo@Dres','experiment':'mysteryGoo','soi':'Dres'},
# LOCATION_ID+123:{'name':'mysteryGoo@Duna','experiment':'mysteryGoo','soi':'Duna'},
# LOCATION_ID+124:{'name':'mysteryGoo@Eeloo','experiment':'mysteryGoo','soi':'Eeloo'},
# LOCATION_ID+125:{'name':'mysteryGoo@Eve','experiment':'mysteryGoo','soi':'Eve'},
# LOCATION_ID+126:{'name':'mysteryGoo@Gilly','experiment':'mysteryGoo','soi':'Gilly'},
# LOCATION_ID+127:{'name':'mysteryGoo@Ike','experiment':'mysteryGoo','soi':'Ike'},
# LOCATION_ID+128:{'name':'mysteryGoo@Jool','experiment':'mysteryGoo','soi':'Jool'},
# LOCATION_ID+129:{'name':'mysteryGoo@Kerbin','experiment':'mysteryGoo','soi':'Kerbin'},
# LOCATION_ID+130:{'name':'mysteryGoo@Laythe','experiment':'mysteryGoo','soi':'Laythe'},
# LOCATION_ID+131:{'name':'mysteryGoo@Minmus','experiment':'mysteryGoo','soi':'Minmus'},
# LOCATION_ID+132:{'name':'mysteryGoo@Moho','experiment':'mysteryGoo','soi':'Moho'},
# LOCATION_ID+133:{'name':'mysteryGoo@Mun','experiment':'mysteryGoo','soi':'Mun'},
# LOCATION_ID+134:{'name':'mysteryGoo@Pol','experiment':'mysteryGoo','soi':'Pol'},
# LOCATION_ID+135:{'name':'mysteryGoo@Sun','experiment':'mysteryGoo','soi':'Sun'},
# LOCATION_ID+136:{'name':'mysteryGoo@Tylo','experiment':'mysteryGoo','soi':'Tylo'},
# LOCATION_ID+137:{'name':'mysteryGoo@Vall','experiment':'mysteryGoo','soi':'Vall'},
# LOCATION_ID+138:{'name':'recovery@Bop','experiment':'recovery','soi':'Bop'},
# LOCATION_ID+139:{'name':'recovery@Dres','experiment':'recovery','soi':'Dres'},
# LOCATION_ID+140:{'name':'recovery@Duna','experiment':'recovery','soi':'Duna'},
# LOCATION_ID+141:{'name':'recovery@Eeloo','experiment':'recovery','soi':'Eeloo'},
# LOCATION_ID+142:{'name':'recovery@Eve','experiment':'recovery','soi':'Eve'},
# LOCATION_ID+143:{'name':'recovery@Gilly','experiment':'recovery','soi':'Gilly'},
# LOCATION_ID+144:{'name':'recovery@Ike','experiment':'recovery','soi':'Ike'},
# LOCATION_ID+145:{'name':'recovery@Jool','experiment':'recovery','soi':'Jool'},
# LOCATION_ID+146:{'name':'recovery@Kerbin','experiment':'recovery','soi':'Kerbin'},
# LOCATION_ID+147:{'name':'recovery@Laythe','experiment':'recovery','soi':'Laythe'},
# LOCATION_ID+148:{'name':'recovery@Minmus','experiment':'recovery','soi':'Minmus'},
# LOCATION_ID+149:{'name':'recovery@Moho','experiment':'recovery','soi':'Moho'},
# LOCATION_ID+150:{'name':'recovery@Mun','experiment':'recovery','soi':'Mun'},
# LOCATION_ID+151:{'name':'recovery@Pol','experiment':'recovery','soi':'Pol'},
# LOCATION_ID+152:{'name':'recovery@Sun','experiment':'recovery','soi':'Sun'},
# LOCATION_ID+153:{'name':'recovery@Tylo','experiment':'recovery','soi':'Tylo'},
# LOCATION_ID+154:{'name':'recovery@Vall','experiment':'recovery','soi':'Vall'},
# LOCATION_ID+155:{'name':'seismicScan@Bop','experiment':'seismicScan','soi':'Bop'},
# LOCATION_ID+156:{'name':'seismicScan@Dres','experiment':'seismicScan','soi':'Dres'},
# LOCATION_ID+157:{'name':'seismicScan@Duna','experiment':'seismicScan','soi':'Duna'},
# LOCATION_ID+158:{'name':'seismicScan@Eeloo','experiment':'seismicScan','soi':'Eeloo'},
# LOCATION_ID+159:{'name':'seismicScan@Eve','experiment':'seismicScan','soi':'Eve'},
# LOCATION_ID+160:{'name':'seismicScan@Gilly','experiment':'seismicScan','soi':'Gilly'},
# LOCATION_ID+161:{'name':'seismicScan@Ike','experiment':'seismicScan','soi':'Ike'},
# LOCATION_ID+162:{'name':'seismicScan@Kerbin','experiment':'seismicScan','soi':'Kerbin'},
# LOCATION_ID+163:{'name':'seismicScan@Laythe','experiment':'seismicScan','soi':'Laythe'},
# LOCATION_ID+164:{'name':'seismicScan@Minmus','experiment':'seismicScan','soi':'Minmus'},
# LOCATION_ID+165:{'name':'seismicScan@Moho','experiment':'seismicScan','soi':'Moho'},
# LOCATION_ID+166:{'name':'seismicScan@Mun','experiment':'seismicScan','soi':'Mun'},
# LOCATION_ID+167:{'name':'seismicScan@Pol','experiment':'seismicScan','soi':'Pol'},
# LOCATION_ID+168:{'name':'seismicScan@Tylo','experiment':'seismicScan','soi':'Tylo'},
# LOCATION_ID+169:{'name':'seismicScan@Vall','experiment':'seismicScan','soi':'Vall'},
# LOCATION_ID+170:{'name':'surfaceSample@Bop','experiment':'surfaceSample','soi':'Bop'},
# LOCATION_ID+171:{'name':'surfaceSample@Dres','experiment':'surfaceSample','soi':'Dres'},
# LOCATION_ID+172:{'name':'surfaceSample@Duna','experiment':'surfaceSample','soi':'Duna'},
# LOCATION_ID+173:{'name':'surfaceSample@Eeloo','experiment':'surfaceSample','soi':'Eeloo'},
# LOCATION_ID+174:{'name':'surfaceSample@Eve','experiment':'surfaceSample','soi':'Eve'},
# LOCATION_ID+175:{'name':'surfaceSample@Gilly','experiment':'surfaceSample','soi':'Gilly'},
# LOCATION_ID+176:{'name':'surfaceSample@Ike','experiment':'surfaceSample','soi':'Ike'},
# LOCATION_ID+177:{'name':'surfaceSample@Kerbin','experiment':'surfaceSample','soi':'Kerbin'},
# LOCATION_ID+178:{'name':'surfaceSample@Laythe','experiment':'surfaceSample','soi':'Laythe'},
# LOCATION_ID+179:{'name':'surfaceSample@Minmus','experiment':'surfaceSample','soi':'Minmus'},
# LOCATION_ID+180:{'name':'surfaceSample@Moho','experiment':'surfaceSample','soi':'Moho'},
# LOCATION_ID+181:{'name':'surfaceSample@Mun','experiment':'surfaceSample','soi':'Mun'},
# LOCATION_ID+182:{'name':'surfaceSample@Pol','experiment':'surfaceSample','soi':'Pol'},
# LOCATION_ID+183:{'name':'surfaceSample@Tylo','experiment':'surfaceSample','soi':'Tylo'},
# LOCATION_ID+184:{'name':'surfaceSample@Vall','experiment':'surfaceSample','soi':'Vall'},
# LOCATION_ID+185:{'name':'temperatureScan@Bop','experiment':'temperatureScan','soi':'Bop'},
# LOCATION_ID+186:{'name':'temperatureScan@Dres','experiment':'temperatureScan','soi':'Dres'},
# LOCATION_ID+187:{'name':'temperatureScan@Duna','experiment':'temperatureScan','soi':'Duna'},
# LOCATION_ID+188:{'name':'temperatureScan@Eeloo','experiment':'temperatureScan','soi':'Eeloo'},
# LOCATION_ID+189:{'name':'temperatureScan@Eve','experiment':'temperatureScan','soi':'Eve'},
# LOCATION_ID+190:{'name':'temperatureScan@Gilly','experiment':'temperatureScan','soi':'Gilly'},
# LOCATION_ID+191:{'name':'temperatureScan@Ike','experiment':'temperatureScan','soi':'Ike'},
# LOCATION_ID+192:{'name':'temperatureScan@Jool','experiment':'temperatureScan','soi':'Jool'},
# LOCATION_ID+193:{'name':'temperatureScan@Kerbin','experiment':'temperatureScan','soi':'Kerbin'},
# LOCATION_ID+194:{'name':'temperatureScan@Laythe','experiment':'temperatureScan','soi':'Laythe'},
# LOCATION_ID+195:{'name':'temperatureScan@Minmus','experiment':'temperatureScan','soi':'Minmus'},
# LOCATION_ID+196:{'name':'temperatureScan@Moho','experiment':'temperatureScan','soi':'Moho'},
# LOCATION_ID+197:{'name':'temperatureScan@Mun','experiment':'temperatureScan','soi':'Mun'},
# LOCATION_ID+198:{'name':'temperatureScan@Pol','experiment':'temperatureScan','soi':'Pol'},
# LOCATION_ID+199:{'name':'temperatureScan@Sun','experiment':'temperatureScan','soi':'Sun'},
# LOCATION_ID+200:{'name':'temperatureScan@Tylo','experiment':'temperatureScan','soi':'Tylo'},
# LOCATION_ID+201:{'name':'temperatureScan@Vall','experiment':'temperatureScan','soi':'Vall'},

# %%
with open('techs.txt', 'r') as f:
    data = f.read().strip().split('\n')
    for i, tech in enumerate(data):
        print(f'ITEM_ID+{i}:ItemData(IC. , 1, "", "{tech}"),')
# Out:
# ITEM_ID+-1:ItemData(IC. , 1, "", "start"),
# ITEM_ID+0:ItemData(IC. , 1, "", "basicRocketry"),
# ITEM_ID+1:ItemData(IC. , 1, "", "engineering101"),
# ITEM_ID+2:ItemData(IC. , 1, "", "survivability"),
# ITEM_ID+3:ItemData(IC. , 1, "", "stability"),
# ITEM_ID+4:ItemData(IC. , 1, "", "generalRocketry"),
# ITEM_ID+5:ItemData(IC. , 1, "", "aviation"),
# ITEM_ID+6:ItemData(IC. , 1, "", "basicScience"),
# ITEM_ID+7:ItemData(IC. , 1, "", "flightControl"),
# ITEM_ID+8:ItemData(IC. , 1, "", "advRocketry"),
# ITEM_ID+9:ItemData(IC. , 1, "", "generalConstruction"),
# ITEM_ID+10:ItemData(IC. , 1, "", "propulsionSystems"),
# ITEM_ID+11:ItemData(IC. , 1, "", "spaceExploration"),
# ITEM_ID+12:ItemData(IC. , 1, "", "advFlightControl"),
# ITEM_ID+13:ItemData(IC. , 1, "", "landing"),
# ITEM_ID+14:ItemData(IC. , 1, "", "aerodynamicSystems"),
# ITEM_ID+15:ItemData(IC. , 1, "", "electrics"),
# ITEM_ID+16:ItemData(IC. , 1, "", "heavyRocketry"),
# ITEM_ID+17:ItemData(IC. , 1, "", "fuelSystems"),
# ITEM_ID+18:ItemData(IC. , 1, "", "advConstruction"),
# ITEM_ID+19:ItemData(IC. , 1, "", "miniaturization"),
# ITEM_ID+20:ItemData(IC. , 1, "", "actuators"),
# ITEM_ID+21:ItemData(IC. , 1, "", "commandModules"),
# ITEM_ID+22:ItemData(IC. , 1, "", "heavierRocketry"),
# ITEM_ID+23:ItemData(IC. , 1, "", "precisionEngineering"),
# ITEM_ID+24:ItemData(IC. , 1, "", "advExploration"),
# ITEM_ID+25:ItemData(IC. , 1, "", "specializedControl"),
# ITEM_ID+26:ItemData(IC. , 1, "", "advLanding"),
# ITEM_ID+27:ItemData(IC. , 1, "", "supersonicFlight"),
# ITEM_ID+28:ItemData(IC. , 1, "", "advFuelSystems"),
# ITEM_ID+29:ItemData(IC. , 1, "", "advElectrics"),
# ITEM_ID+30:ItemData(IC. , 1, "", "specializedConstruction"),
# ITEM_ID+31:ItemData(IC. , 1, "", "precisionPropulsion"),
# ITEM_ID+32:ItemData(IC. , 1, "", "advAerodynamics"),
# ITEM_ID+33:ItemData(IC. , 1, "", "heavyLanding"),
# ITEM_ID+34:ItemData(IC. , 1, "", "scienceTech"),
# ITEM_ID+35:ItemData(IC. , 1, "", "unmannedTech"),
# ITEM_ID+36:ItemData(IC. , 1, "", "nuclearPropulsion"),
# ITEM_ID+37:ItemData(IC. , 1, "", "advMetalworks"),
# ITEM_ID+38:ItemData(IC. , 1, "", "fieldScience"),
# ITEM_ID+39:ItemData(IC. , 1, "", "highAltitudeFlight"),
# ITEM_ID+40:ItemData(IC. , 1, "", "largeVolumeContainment"),
# ITEM_ID+41:ItemData(IC. , 1, "", "composites"),
# ITEM_ID+42:ItemData(IC. , 1, "", "electronics"),
# ITEM_ID+43:ItemData(IC. , 1, "", "largeElectrics"),
# ITEM_ID+44:ItemData(IC. , 1, "", "heavyAerodynamics"),
# ITEM_ID+45:ItemData(IC. , 1, "", "ionPropulsion"),
# ITEM_ID+46:ItemData(IC. , 1, "", "hypersonicFlight"),
# ITEM_ID+47:ItemData(IC. , 1, "", "nanolathing"),
# ITEM_ID+48:ItemData(IC. , 1, "", "advUnmanned"),
# ITEM_ID+49:ItemData(IC. , 1, "", "metaMaterials"),
# ITEM_ID+50:ItemData(IC. , 1, "", "veryHeavyRocketry"),
# ITEM_ID+51:ItemData(IC. , 1, "", "advScienceTech"),
# ITEM_ID+52:ItemData(IC. , 1, "", "advancedMotors"),
# ITEM_ID+53:ItemData(IC. , 1, "", "specializedElectrics"),
# ITEM_ID+54:ItemData(IC. , 1, "", "highPerformanceFuelSystems"),
# ITEM_ID+55:ItemData(IC. , 1, "", "experimentalAerodynamics"),
# ITEM_ID+56:ItemData(IC. , 1, "", "automation"),
# ITEM_ID+57:ItemData(IC. , 1, "", "aerospaceTech"),
# ITEM_ID+58:ItemData(IC. , 1, "", "largeUnmanned"),
# ITEM_ID+59:ItemData(IC. , 1, "", "experimentalScience"),
# ITEM_ID+60:ItemData(IC. , 1, "", "experimentalMotors"),
# ITEM_ID+61:ItemData(IC. , 1, "", "experimentalElectrics"),
